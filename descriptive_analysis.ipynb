# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # Descriptive Analysis

# %%
doctor_false=open("doctor_false.txt").readlines()
doctor_true=open("doctor_true.txt").readlines()
restaurant_false=open("restaurant_false.txt").readlines()
restaurant_true=open("restaurant_true.txt").readlines()

# %%
for i in range(0,len(doctor_false)):
  doctor_false[i]=doctor_false[i][:-1]
for i in range(0,len(doctor_true)):
  doctor_true[i]=doctor_true[i][:-1]
for i in range(0,len(restaurant_false)):
  restaurant_false[i]=restaurant_false[i][:-1]
for i in range(0,len(restaurant_true)):
  restaurant_true[i]=restaurant_true[i][:-1]

# %%
def mean(list):
     return np.mean(list)
def median(list):
     return np.median(list)

# %% [markdown]
# # restaurant_false

# %%
vocabulary=get_vocabulary(df_res_train)
restaurant_false_nlw=[]
restaurant_false_ns=[]
restaurant_false_nrw=[]
restaurant_false_tmu=[]
for string in restaurant_false:
    restaurant_false_tmu.append(total_most_used(string,vocabulary))
    restaurant_false_nlw.append(num_long_words(string))
    restaurant_false_ns.append(num_sentences(string))
    restaurant_false_nrw.append(num_repeated_words(string))

# %%
mean(restaurant_false_nlw)
# Out:
# 36.51

# %%
median(restaurant_false_nlw)
# Out:
# 31.0

# %%
sns.set_palette("hls") 
sns.distplot(restaurant_false_nlw,color="b",bins=20,kde=True)
plt.title("restaurant_false_nlw")
plt.show()

# %%
mean(restaurant_false_ns)
# Out:
# 8.995

# %%
median(restaurant_false_ns)
# Out:
# 8.0

# %%
sns.set_palette("hls") 
sns.distplot(restaurant_false_ns,color="b",bins=20,kde=True)
plt.title("restaurant_false_ns")
plt.show()

# %%
mean(restaurant_false_nrw)
# Out:
# 44.185

# %%
median(restaurant_false_nrw)
# Out:
# 36.0

# %%
sns.set_palette("hls") 
sns.distplot(restaurant_false_nrw,color="b",bins=20,kde=True)
plt.title("restaurant_false_nrw")
plt.show()

# %%
mean(restaurant_false_tmu)
# Out:
# 38.795

# %%
median(restaurant_false_tmu)
# Out:
# 35.5

# %%
sns.set_palette("hls") 
sns.distplot(restaurant_false_tmu,color="b",bins=20,kde=True)
plt.title("restaurant_false_tmu")
plt.show()

# %% [markdown]
# # restaurant_true

# %%
restaurant_true_nlw=[]
restaurant_true_ns=[]
restaurant_true_nrw=[]
restaurant_true_tmu=[]
for string in restaurant_true:
    restaurant_true_tmu.append(total_most_used(string,vocabulary))
    restaurant_true_nlw.append(num_long_words(string))
    restaurant_true_ns.append(num_sentences(string))
    restaurant_true_nrw.append(num_repeated_words(string))

# %%
mean(restaurant_true_nlw)
# Out:
# 38.315

# %%
median(restaurant_true_nlw)
# Out:
# 31.5

# %%
sns.set_palette("hls") 
sns.distplot(restaurant_true_nlw,color="b",bins=20,kde=True)
plt.title("restaurant_true_nlw")
plt.show()

# %%
mean(restaurant_true_ns)
# Out:
# 10.515

# %%
median(restaurant_true_ns)
# Out:
# 9.0

# %%
sns.set_palette("hls") 
sns.distplot(restaurant_true_ns,color="b",bins=20,kde=True)
plt.title("restaurant_true_ns")
plt.show()

# %%
mean(restaurant_true_nrw)
# Out:
# 46.93

# %%
median(restaurant_true_nrw)
# Out:
# 33.5

# %%
sns.set_palette("hls") 
sns.distplot(restaurant_true_nrw,color="b",bins=20,kde=True)
plt.title("restaurant_true_nrw")
plt.show()

# %%
mean(restaurant_true_tmu)
# Out:
# 38.37

# %%
median(restaurant_true_tmu)
# Out:
# 32.5

# %%
sns.set_palette("hls") 
sns.distplot(restaurant_true_tmu,color="b",bins=20,kde=True)
plt.title("restaurant_true_tmu")
plt.show()
